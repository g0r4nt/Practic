# %%
#1 часть
import numpy as np # линейная алгебра
import pandas as pd # обработка данных


# Файлы входных данных доступны только для чтения каталоге "../input/"

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

#Устанавливаем параметры для работы в формате float
pd.options.display.float_format = '{:20,.0f}'.format

ds = pd.read_csv("/Users/HOME/Desktop/code/Top Youtubers Dataset.csv",sep=",",index_col='Rank',encoding='cp1252')

def no(): 
    return null

print(ds)
# Out:
#                                            Youtuber  Subscribers  \
# Rank
# 1                                           MrBeast    284000000
# 2                                          T-Series    268000000
# 3                                    YouTube Movies    181000000
# 4                        Cocomelon - Nursery Rhymes    177000000
# 5                                         SET India    174000000
# ...                                             ...          ...
# 996   Peppa Pig em Português Brasil - Canal Oficial     14500000
# 997                                     Bie The Ska     14500000
# 998                                         Cyprien     14500000
# 999                                   YANA CHIRKINA     14500000
# 1000         Tayo Bus Kecil - Tayo Bahasa Indonesia     14500000
#
#               Video Views  Video Count          Category  Started
# Rank
# 1          52,402,898,889          803     Entertainment     2012
# 2         258,624,000,000        21237             Music     2006
# 3                       0            0  Film & Animation     2015
# 4         182,881,000,000         1188         Education     2006
# 5         165,395,000,000       139720             Shows     2006
# ...                   ...          ...               ...      ...
# 996         5,040,493,786         1657  Film & Animation     2014
# 997         4,924,884,083         1832     Entertainment     2006
# 998         3,194,240,254          252            Comedy     2007
# 999        10,487,538,339         2189            Sports     2018
# 1000        7,251,267,100         1260  Film & Animation     2016
#
# [1000 rows x 6 columns]

# %%
#2 часть
ds["Views Per Video"] = (
    ds["Video Views"] / ds["Video Count"]
)
ds

ds = ds[ds['Video Count'] != 0] #Фильтры настроены так, чтобы исключить каналы с 0 видео

ds = ds[ds['Started'] > 2000 ] #Фильтруем данные за период с 200 года

    
ds = ds.reset_index() #Создаем индекс (добавляем к нему 1), чтобы мы могли найти по индексу в списке


ds["Rank Delta"] = (
    ds["Rank"] - ds.index.to_numpy()   #Создаем показатель разности между старыми и новыми ранками
)

ds

year_started_counts = ds.Started.value_counts() #Создаем новую серию, для графика учитывается начатый год
print(year_started_counts) 

rank_delta_counts = ds.value_counts("Rank Delta") #Создаем новую серию, для графика учитывается начатый год
print(rank_delta_counts)
# Out:
# Started
# 2014    100
# 2015     83
# 2016     77
# 2013     74
# 2011     73
# 2017     72
# 2012     70
# 2006     60
# 2018     53
# 2021     53
# 2009     47
# 2020     47
# 2008     41
# 2007     38
# 2019     36
# 2010     35
# 2005     18
# 2022      7
# 2023      5
# 2024      1
# Name: count, dtype: int64
# Rank Delta
# 10    395
# 11    193
# 8     125
# 7      99
# 5      93
# 6      35
# 9      31
# 3       7
# 4       7
# 2       3
# 1       2
# Name: count, dtype: int64

# %%
#3 часть
# Сортируем серии, чтобы они располагались в хронологическом порядке
year_started_counts = year_started_counts.sort_index()
ys_graph = year_started_counts.plot(kind='bar',title ="Number of Top 1000 Channels Started by Year") #Сохраняем график, на всякий случай

#Категория доступа подсчитывается в значении value_counts и показывается в диаграмме
category_counts = ds.Category.value_counts()
print(category_counts)
category_graph = category_counts.plot(kind='bar', title = 'Channels by Channel Category')

cat_view_p_vid = ds.groupby(['Category'])[["Views Per Video"]].mean()
print(cat_view_p_vid)
cat_view_p_vid.plot(kind = 'bar', ylabel="Views (Ten-Millions)")
# Out:
# Category
# Entertainment            269
# Music                    172
# People & Blogs           152
# Gaming                    92
# Comedy                    71
# Film & Animation          44
# Education                 41
# Howto & Style             28
# News & Politics           27
# Sports                    17
# Science & Technology      15
# Shows                     13
# Pets & Animals             6
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Name: count, dtype: int64
#                            Views Per Video
# Category
# Autos & Vehicles                 5,902,920
# Comedy                          16,151,198
# Education                       42,429,184
# Entertainment                   11,100,706
# Film & Animation                22,004,196
# Gaming                           5,825,053
# Howto & Style                    7,030,186
# Movies                           2,182,529
# Music                           71,668,449
# News & Politics                  1,872,592
# Nonprofits & Activism              460,177
# People & Blogs                  16,857,789
# Pets & Animals                  14,446,282
# Science & Technology             6,850,106
# Shows                            4,997,962
# Sports                           9,951,149
# Trailers                         2,952,883
# <Axes: xlabel='Category', ylabel='Views (Ten-Millions)'>

# %%
import pandas as pd
df = pd.read_csv("/Users/HOME/Desktop/code/Top Youtubers Dataset.csv",sep=",",index_col='Rank',encoding='cp1252')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Youtuber     1000 non-null   object
#  1   Subscribers  1000 non-null   int64
#  2   Video Views  1000 non-null   float64
#  3   Video Count  1000 non-null   int64
#  4   Category     957 non-null    object
#  5   Started      1000 non-null   int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 54.7+ KB

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

df = pd.read_csv("/Users/HOME/Desktop/code/Top Youtubers Dataset.csv",sep=",",index_col='Rank',encoding='cp1252')

df['Category'].fillna(df['Category'].mode()[0], inplace=True)

# Преобразование категориальной переменной 'Category' в числовую
label_encoder = LabelEncoder()
df['Category'] = label_encoder.fit_transform(df['Category'])

# Нормализация числовых признаков
scaler = StandardScaler()
numerical_features = ['Subscribers', 'Video Views', 'Video Count']
df[numerical_features] = scaler.fit_transform(df[numerical_features])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File __init__.cython-30.pxd:1024, in numpy.import_array()
#
# ImportError: DLL load failed while importing _multiarray_umath: Не найден указанный модуль.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2 from sklearn.preprocessing import LabelEncoder, StandardScaler
# ----> 3 from sklearn.model_selection import train_test_split
#       4 from sklearn.linear_model import LinearRegression
#       5 from sklearn.metrics import mean_squared_error
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\__init__.py:5
#       1 """Tools for model selection, such as cross validation and hyper-parameter tuning."""
#       3 import typing
# ----> 5 from ._classification_threshold import (
#       6     FixedThresholdClassifier,
#       7     TunedThresholdClassifierCV,
#       8 )
#       9 from ._plot import LearningCurveDisplay, ValidationCurveDisplay
#      10 from ._search import GridSearchCV, ParameterGrid, ParameterSampler, RandomizedSearchCV
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_classification_threshold.py:14
#       6 from ..base import (
#       7     BaseEstimator,
#       8     ClassifierMixin,
#    (...)
#      11     clone,
#      12 )
#      13 from ..exceptions import NotFittedError
# ---> 14 from ..metrics import (
#      15     check_scoring,
#      16     get_scorer_names,
#      17 )
#      18 from ..metrics._scorer import _BaseScorer
#      19 from ..utils import _safe_indexing
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\__init__.py:3
#       1 """Score functions, performance metrics, pairwise metrics and distance computations."""
# ----> 3 from . import cluster
#       4 from ._classification import (
#       5     accuracy_score,
#       6     balanced_accuracy_score,
#    (...)
#      24     zero_one_loss,
#      25 )
#      26 from ._dist_metrics import DistanceMetric
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\cluster\__init__.py:25
#       8 from ._bicluster import consensus_score
#       9 from ._supervised import (
#      10     adjusted_mutual_info_score,
#      11     adjusted_rand_score,
#    (...)
#      23     v_measure_score,
#      24 )
# ---> 25 from ._unsupervised import (
#      26     calinski_harabasz_score,
#      27     davies_bouldin_score,
#      28     silhouette_samples,
#      29     silhouette_score,
#      30 )
#      32 __all__ = [
#      33     "adjusted_mutual_info_score",
#      34     "normalized_mutual_info_score",
#    (...)
#      51     "consensus_score",
#      52 ]
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:23
#      17 from ...utils._array_api import _atol_for_type
#      18 from ...utils._param_validation import (
#      19     Interval,
#      20     StrOptions,
#      21     validate_params,
#      22 )
# ---> 23 from ..pairwise import _VALID_METRICS, pairwise_distances, pairwise_distances_chunked
#      26 def check_number_of_labels(n_labels, n_samples):
#      27     """Check that number of labels are valid.
#      28
#      29     Parameters
#    (...)
#      35         Number of samples.
#      36     """
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:50
#      48 from ..utils.parallel import Parallel, delayed
#      49 from ..utils.validation import _num_samples, check_non_negative
# ---> 50 from ._pairwise_distances_reduction import ArgKmin
#      51 from ._pairwise_fast import _chi2_kernel_fast, _sparse_manhattan
#      54 # Utility Functions
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\__init__.py:94
#       1 #
#       2 # Pairwise Distances Reductions
#       3 # =============================
#    (...)
#      91 #    (see :class:`MiddleTermComputer{32,64}`).
#      92 #
# ---> 94 from ._dispatcher import (
#      95     ArgKmin,
#      96     ArgKminClassMode,
#      97     BaseDistancesReductionDispatcher,
#      98     RadiusNeighbors,
#      99     RadiusNeighborsClassMode,
#     100     sqeuclidean_row_norms,
#     101 )
#     103 __all__ = [
#     104     "BaseDistancesReductionDispatcher",
#     105     "ArgKmin",
#    (...)
#     109     "sqeuclidean_row_norms",
#     110 ]
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py:8
#       5 from scipy.sparse import issparse
#       7 from ... import get_config
# ----> 8 from .._dist_metrics import (
#       9     BOOL_METRICS,
#      10     METRIC_MAPPING64,
#      11     DistanceMetric,
#      12 )
#      13 from ._argkmin import (
#      14     ArgKmin32,
#      15     ArgKmin64,
#      16 )
#      17 from ._argkmin_classmode import (
#      18     ArgKminClassMode32,
#      19     ArgKminClassMode64,
#      20 )
#
# File sklearn\\metrics\\_dist_metrics.pyx:8, in init sklearn.metrics._dist_metrics()
#
# File __init__.cython-30.pxd:1026, in numpy.import_array()
#
# ImportError: numpy._core.multiarray failed to import
